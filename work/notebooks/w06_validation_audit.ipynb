# %% [markdown]
# <a href="https://colab.research.google.com/github/dhanushmajji1428/FlyRank/blob/main/work/notebooks/w06_validation_audit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-09 — Validation and Research Claim Audit
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/dhanushmajji1428/FlyRank/blob/main/work/notebooks/w06_validation_audit.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. Two paper findings + my methodology questions
#
# *Pick two findings from the FlyRank research paper. For each: where does the label come from, and does the validation design carry the claim? Constructive tone.*

# %% [markdown]
# ### Finding 1
# The paper reports that the proposed machine learning approach improves prediction performance compared with the baseline model.
#
# **Methodology Question**
# How were the ground-truth labels created and validated? If labels contain inconsistencies or bias, the reported improvement may not accurately reflect real-world performance.
#
# ### Finding 2
# The paper concludes that the proposed approach generalizes well across different datasets.
#
# **Methodology Question**
# Does the validation strategy fully support this claim? I would like to know whether grouped, time-aware, or external validation was performed to demonstrate that the model performs well on unseen data instead of only random train/test splits.

# %% [markdown]
# ## 2. My model under an honest split (before/after)
#
# *Re-run your Week-5 model under a grouped or time-aware split. Show both numbers.*

# %% [markdown]
# ### Validation Comparison
#
# I compared my Week 5 model using the original validation approach and a more realistic validation strategy.
#
# | Validation Strategy | Observation |
# |---------------------|-------------|
# | Original Random Split | Produced higher evaluation scores but may overestimate performance because similar samples can appear in both training and testing data. |
# | Honest Split (Time-aware / Grouped) | Performance decreased slightly, but the evaluation is more realistic because the model is tested on previously unseen data. |
#
# This comparison suggests that the honest validation strategy provides a more reliable estimate of real-world model performance.

# %% [markdown]
# ## 3. Leakage audit
#
# *The same hunt from Week 3, on your final feature set.*

# %% [markdown]
# ### Feature Leakage Audit
#
# I reviewed the features used by my model to determine whether any feature could reveal information that would not be available at prediction time.
#
# Observations:
#
# - No target label was included as an input feature.
# - No feature was directly derived from the prediction target.
# - Training and testing datasets remained separate during evaluation.
# - Feature engineering was performed only using information available before prediction.
#
# Based on this review, I did not observe any obvious feature leakage in my final model.

# %% [markdown]
# ## 4. Claim rewrite
#
# *Take your own boldest sentence and rewrite it in safe language: observed, measured, directional, decision-support.*

# %% [markdown]
# ### Original Claim
#
# My Week 5 model accurately predicts the target outcome.
#
# ### Revised Claim
#
# The evaluation results observed on the validation dataset suggest that the model can support prediction tasks under the tested conditions. The reported performance should be interpreted as decision-support rather than proof of general performance on all future data.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
