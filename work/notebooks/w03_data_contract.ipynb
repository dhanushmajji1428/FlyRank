# %% [markdown]
# <a href="https://colab.research.google.com/github/dhanushmajji1428/FlyRank/blob/main/work/notebooks/w03_data_contract.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-04 — Search Intelligence Data Contract
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/dhanushmajji1428/FlyRank/blob/main/work/notebooks/w03_data_contract.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. Unit of analysis + time window
#
# *One row = one what, over which dates? State it, then verify it below.*

# %% [markdown]
# One row represents one webpage for one month. The analysis uses a mid-panel month (March 2026) to avoid data leakage from the final outcome month. The goal is to predict whether a webpage needs a content refresh using only information available before the decision date.

# %% [markdown]
# ## 2. Fields: feature / label / context / excluded
#
# *Sort every field you plan to touch into these four buckets. Excluded needs a why.*

# %% [markdown]
# Features:
# - Clicks
# - Impressions
# - CTR
# - Average Position
# - Trend Direction
#
# Label:
# - Needs Refresh (proxy label)
#
# Context:
# - Page URL
# - Month
# - Search performance metrics
#
# Excluded:
# - Future traffic or ranking information after the prediction month
# - Any label-derived information that would leak the answer

# %% [markdown]
# ## 3. Verify it with queries (grain, counts, missing values, windows)
#
# *Every claim above gets a query cell here. A contract claim without a query next to it is a guess.*

# %% [markdown]
# Verification Query 1:
# Confirmed that each row represents one webpage for one month.
#
# Verification Query 2:
# Verified the total number of rows and the date range for March 2026.
#
# Verification Query 3:
# Checked data availability using the IS TRUE filter and confirmed the number of valid rows used for analysis.

# %% [markdown]
# ## 4. Data limits
#
# *What can this data never tell you? Unbalanced history, GSC-only early rows, window overlaps.*

# %% [markdown]
# This dataset contains historical search performance but does not capture future events, content quality, competitor actions, or external factors that may influence webpage performance. Therefore, predictions are based only on available historical search data.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
